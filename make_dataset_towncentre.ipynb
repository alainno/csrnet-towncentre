# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %%
images = loadmat('data/ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_1.mat',variable_names='IMAGES',appendmat=True).get('IMAGES')

type(images)
#imgplot = plt.imshow(images)
#plt.show()
# Out:
# NoneType

# %%
import scipy.io as io

mat = io.loadmat('data/ShanghaiTech/part_B/test_data/ground-truth/GT_IMG_2.mat')
type(mat)
# Out:
# dict

# %%
#print(mat)

gt = mat["image_info"][0,0][0,0][0]

type(gt)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('data/ShanghaiTech/part_B/test_data/images/IMG_2.jpg')
imgplot = plt.imshow(img)

#a=[[297,274],[350,323],[468,318],[5,2]]
plt.plot(*zip(*gt), marker='o', color='r', ls='')

plt.show()

# %%
import numpy as np
import scipy.io

#x = np.linspace(0, 2 * np.pi, 100)
#y = np.cos(x)
image_info = np.array([(1,2),(2,3)])

scipy.io.savemat('test.mat', dict(image_info=image_info))

# %%
mat = io.loadmat('test.mat')
type(mat)
print(mat)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Thu Jul  9 10:21:39 2020', '__version__': '1.0', '__globals__': [], 'image_info': array([[1, 2],
#        [2, 3]])}
